# %% [markdown]
# # Timeseries classification from scratch
#
# This example shows how to do timeseries classification from scratch, starting from raw CSV
# timeseries files on disk. We demonstrate the workflow on the FordA dataset from the [UCR/UEA
# archive](https://www.cs.ucr.edu/~eamonn/time_series_data_2018/).

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2023-01-18 14:38:59.964646: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load the data: the FordA dataset
#
# ### Dataset description
#
# The dataset we are using here is called FordA. The data comes from the UCR archive. The dataset contains 3601 training instances and another 1320 testing instances. Each timeseries corresponds to a measurement of engine noise captured by a motor sensor. For this task, the goal is to automatically detect the presence of a specific issue with the engine. The problem is a balanced binary classification task. The full description of this dataset can be found [here](http://www.j-wichard.de/publications/FordPaper.pdf).

# %% [markdown]
# ### Read the TSV data
#
# We will use the FordA_TRAIN file for training and the FordA_TEST file for testing. The simplicity of this dataset allows us to demonstrate effectively how to use ConvNets for timeseries classification. In this file, the first column corresponds to the label.

# %%
def read_ucr_dataset(filename):
    root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"
    data = np.loadtxt(root_url + filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)

x_train, y_train = read_ucr_dataset("FordA_TRAIN.tsv")
x_test, y_test = read_ucr_dataset("FordA_TEST.tsv")

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each class in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))

plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# ## Standardize the data
#
# Our timeseries are already in a single length (500). However, their values are usually in various ranges. This is not ideal for a neural network; in general we should seek to make the input values normalized. For this specific dataset, the data is already z-normalized: each timeseries sample has a mean equal to zero and a standard deviation equal to one. This type of normalization is very common for timeseries classification problems, see Bagnall et al. (2016).

# %%
# Note that the timeseries data used here are univariate, meaning we only have one channel 
# per timeseries example. We will therefore transform the timeseries into a multivariate 
# one with one channel using a simple reshaping via numpy. This will allow us to construct 
# a model that is easily applicable to multivariate time series.
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count the 
# number of classes beforehand.
num_classes = len(np.unique(y_train))

# Now we shuffle the training set because we will be using the validation_split option 
# later when training.
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# Standardize the labels to positive integers. The expected labels will then be 0 and 1.
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3601, 500, 1), (3601,), (1320, 500, 1), (1320,))

# %% [markdown]
# ## Build a model
#
# We build a Fully Convolutional Neural Network originally proposed in this [paper](https://arxiv.org/abs/1611.06455).
# The implementation is based on the TF 2 version provided [here](https://github.com/hfawaz/dl-4-tsc/).
# The following hyperparameters (kernel_size, filters, the usage of BatchNorm) were found via
# random search using [KerasTuner](https://github.com/keras-team/keras-tuner).

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# 2023-01-18 14:39:15.554953: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 500, 1)]          0
#
#  conv1d (Conv1D)             (None, 500, 64)           256
#
#  batch_normalization (BatchN  (None, 500, 64)          256
#  ormalization)
#
#  re_lu (ReLU)                (None, 500, 64)           0
#
#  conv1d_1 (Conv1D)           (None, 500, 64)           12352
#
#  batch_normalization_1 (Batc  (None, 500, 64)          256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 500, 64)           0
#
#  conv1d_2 (Conv1D)           (None, 500, 64)           12352
#
#  batch_normalization_2 (Batc  (None, 500, 64)          256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 500, 64)           0
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 25,858
# Trainable params: 25,474
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
x_train = x_train[:1000]
y_train = y_train[:1000]

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 5s 91ms/step - loss: 0.4456 - sparse_categorical_accuracy: 0.7825 - val_loss: 0.7063 - val_sparse_categorical_accuracy: 0.4500 - lr: 0.0010
# Epoch 2/50
# 25/25 [==============================] - 2s 87ms/step - loss: 0.4356 - sparse_categorical_accuracy: 0.7925 - val_loss: 0.6507 - val_sparse_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 3/50
# 25/25 [==============================] - 2s 92ms/step - loss: 0.4224 - sparse_categorical_accuracy: 0.7812 - val_loss: 0.6981 - val_sparse_categorical_accuracy: 0.5200 - lr: 0.0010
# Epoch 4/50
# 25/25 [==============================] - 2s 98ms/step - loss: 0.4149 - sparse_categorical_accuracy: 0.7763 - val_loss: 0.7415 - val_sparse_categorical_accuracy: 0.5150 - lr: 0.0010
# Epoch 5/50
# 25/25 [==============================] - 2s 98ms/step - loss: 0.4119 - sparse_categorical_accuracy: 0.7875 - val_loss: 0.6371 - val_sparse_categorical_accuracy: 0.6050 - lr: 0.0010
# Epoch 6/50
# 25/25 [==============================] - 2s 100ms/step - loss: 0.4234 - sparse_categorical_accuracy: 0.7775 - val_loss: 0.6241 - val_sparse_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 7/50
# 25/25 [==============================] - 2s 97ms/step - loss: 0.3906 - sparse_categorical_accuracy: 0.8062 - val_loss: 0.7998 - val_sparse_categorical_accuracy: 0.4600 - lr: 0.0010
# Epoch 8/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.3930 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.7709 - val_sparse_categorical_accuracy: 0.5050 - lr: 0.0010
# Epoch 9/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.4102 - sparse_categorical_accuracy: 0.7962 - val_loss: 0.6583 - val_sparse_categorical_accuracy: 0.6450 - lr: 0.0010
# Epoch 10/50
# 25/25 [==============================] - 3s 104ms/step - loss: 0.3830 - sparse_categorical_accuracy: 0.8175 - val_loss: 0.6756 - val_sparse_categorical_accuracy: 0.6100 - lr: 0.0010
# Epoch 11/50
# 25/25 [==============================] - 3s 110ms/step - loss: 0.3829 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.4765 - val_sparse_categorical_accuracy: 0.7650 - lr: 0.0010
# Epoch 12/50
# 25/25 [==============================] - 3s 115ms/step - loss: 0.3723 - sparse_categorical_accuracy: 0.8338 - val_loss: 0.4525 - val_sparse_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 13/50
# 25/25 [==============================] - 3s 106ms/step - loss: 0.3873 - sparse_categorical_accuracy: 0.8037 - val_loss: 0.5177 - val_sparse_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 14/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.3976 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.4343 - val_sparse_categorical_accuracy: 0.7800 - lr: 0.0010
# Epoch 15/50
# 25/25 [==============================] - 3s 126ms/step - loss: 0.3898 - sparse_categorical_accuracy: 0.8163 - val_loss: 0.4397 - val_sparse_categorical_accuracy: 0.7350 - lr: 0.0010
# Epoch 16/50
# 25/25 [==============================] - 3s 108ms/step - loss: 0.3954 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.4673 - val_sparse_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 17/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.3646 - sparse_categorical_accuracy: 0.8313 - val_loss: 0.4160 - val_sparse_categorical_accuracy: 0.7750 - lr: 0.0010
# Epoch 18/50
# 25/25 [==============================] - 3s 114ms/step - loss: 0.3615 - sparse_categorical_accuracy: 0.8163 - val_loss: 0.4653 - val_sparse_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 19/50
# 25/25 [==============================] - 3s 122ms/step - loss: 0.3682 - sparse_categorical_accuracy: 0.8238 - val_loss: 0.4327 - val_sparse_categorical_accuracy: 0.7600 - lr: 0.0010
# Epoch 20/50
# 25/25 [==============================] - 3s 118ms/step - loss: 0.3696 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.4555 - val_sparse_categorical_accuracy: 0.7550 - lr: 0.0010
# Epoch 21/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.3711 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.3856 - val_sparse_categorical_accuracy: 0.8300 - lr: 0.0010
# Epoch 22/50
# 25/25 [==============================] - 3s 138ms/step - loss: 0.3713 - sparse_categorical_accuracy: 0.8150 - val_loss: 0.4386 - val_sparse_categorical_accuracy: 0.7700 - lr: 0.0010
# Epoch 23/50
# 25/25 [==============================] - 3s 128ms/step - loss: 0.3536 - sparse_categorical_accuracy: 0.8363 - val_loss: 0.4336 - val_sparse_categorical_accuracy: 0.7550 - lr: 0.0010
# Epoch 24/50
# 25/25 [==============================] - 3s 118ms/step - loss: 0.3422 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.4769 - val_sparse_categorical_accuracy: 0.7450 - lr: 0.0010
# Epoch 25/50
# 25/25 [==============================] - 3s 133ms/step - loss: 0.3572 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.7462 - val_sparse_categorical_accuracy: 0.6950 - lr: 0.0010
# Epoch 26/50
# 25/25 [==============================] - 3s 123ms/step - loss: 0.3755 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.4640 - val_sparse_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 27/50
# 25/25 [==============================] - 3s 119ms/step - loss: 0.3584 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.4132 - val_sparse_categorical_accuracy: 0.7750 - lr: 0.0010
# Epoch 28/50
# 25/25 [==============================] - 3s 128ms/step - loss: 0.3573 - sparse_categorical_accuracy: 0.8313 - val_loss: 0.3688 - val_sparse_categorical_accuracy: 0.8450 - lr: 0.0010
# Epoch 29/50
# 25/25 [==============================] - 3s 127ms/step - loss: 0.3407 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.3727 - val_sparse_categorical_accuracy: 0.8350 - lr: 0.0010
# Epoch 30/50
# 25/25 [==============================] - 3s 119ms/step - loss: 0.3344 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.3704 - val_sparse_categorical_accuracy: 0.7950 - lr: 0.0010
# Epoch 31/50
# 25/25 [==============================] - 3s 135ms/step - loss: 0.3490 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.4657 - val_sparse_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 32/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.3464 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.7654 - val_sparse_categorical_accuracy: 0.6300 - lr: 0.0010
# Epoch 33/50
# 25/25 [==============================] - 3s 124ms/step - loss: 0.3469 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.5673 - val_sparse_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 34/50
# 25/25 [==============================] - 3s 134ms/step - loss: 0.3406 - sparse_categorical_accuracy: 0.8413 - val_loss: 0.3909 - val_sparse_categorical_accuracy: 0.7750 - lr: 0.0010
# Epoch 35/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.3540 - sparse_categorical_accuracy: 0.8300 - val_loss: 1.0835 - val_sparse_categorical_accuracy: 0.6150 - lr: 0.0010
# Epoch 36/50
# 25/25 [==============================] - 3s 121ms/step - loss: 0.3566 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.3815 - val_sparse_categorical_accuracy: 0.8150 - lr: 0.0010
# Epoch 37/50
# 25/25 [==============================] - 3s 126ms/step - loss: 0.3511 - sparse_categorical_accuracy: 0.8375 - val_loss: 0.4015 - val_sparse_categorical_accuracy: 0.7950 - lr: 0.0010
# Epoch 38/50
# 25/25 [==============================] - 3s 126ms/step - loss: 0.3336 - sparse_categorical_accuracy: 0.8562 - val_loss: 0.4867 - val_sparse_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 39/50
# 25/25 [==============================] - 3s 124ms/step - loss: 0.3387 - sparse_categorical_accuracy: 0.8512 - val_loss: 0.4169 - val_sparse_categorical_accuracy: 0.7650 - lr: 0.0010
# Epoch 40/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.3406 - sparse_categorical_accuracy: 0.8313 - val_loss: 0.4359 - val_sparse_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 41/50
# 25/25 [==============================] - 3s 133ms/step - loss: 0.3337 - sparse_categorical_accuracy: 0.8475 - val_loss: 0.3718 - val_sparse_categorical_accuracy: 0.7850 - lr: 0.0010
# Epoch 42/50
# 25/25 [==============================] - 3s 125ms/step - loss: 0.3170 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.4201 - val_sparse_categorical_accuracy: 0.7700 - lr: 0.0010
# Epoch 43/50
# 25/25 [==============================] - 3s 124ms/step - loss: 0.3208 - sparse_categorical_accuracy: 0.8600 - val_loss: 0.3988 - val_sparse_categorical_accuracy: 0.8200 - lr: 0.0010
# Epoch 44/50
# 25/25 [==============================] - 3s 126ms/step - loss: 0.3173 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.4232 - val_sparse_categorical_accuracy: 0.7550 - lr: 0.0010
# Epoch 45/50
# 25/25 [==============================] - 3s 126ms/step - loss: 0.3315 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.4796 - val_sparse_categorical_accuracy: 0.7450 - lr: 0.0010
# Epoch 46/50
# 25/25 [==============================] - 3s 127ms/step - loss: 0.3357 - sparse_categorical_accuracy: 0.8363 - val_loss: 0.3934 - val_sparse_categorical_accuracy: 0.7750 - lr: 0.0010
# Epoch 47/50
# 25/25 [==============================] - 3s 125ms/step - loss: 0.3261 - sparse_categorical_accuracy: 0.8587 - val_loss: 0.3850 - val_sparse_categorical_accuracy: 0.8050 - lr: 0.0010
# Epoch 48/50
# 25/25 [==============================] - 3s 133ms/step - loss: 0.3393 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.3832 - val_sparse_categorical_accuracy: 0.8200 - lr: 0.0010
# Epoch 49/50
# 25/25 [==============================] - 3s 122ms/step - loss: 0.3422 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.3717 - val_sparse_categorical_accuracy: 0.8150 - lr: 5.0000e-04
# Epoch 50/50
# 25/25 [==============================] - 3s 132ms/step - loss: 0.3090 - sparse_categorical_accuracy: 0.8587 - val_loss: 0.3577 - val_sparse_categorical_accuracy: 0.7900 - lr: 5.0000e-04

# %% [markdown]
# ## Evaluate model on test data

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 [==============================] - 1s 12ms/step - loss: 0.3110 - sparse_categorical_accuracy: 0.8591
# Test accuracy 0.8590909242630005
# Test loss 0.3110122084617615

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %% [markdown]
# We can see how the training accuracy reaches almost 0.95 after 100 epochs. However, by observing the validation accuracy we can see how the network still needs training until it reaches almost 0.97 for both the validation and the training accuracy after 200 epochs. Beyond the 200th epoch, if we continue on training, the validation accuracy will start decreasing while the training accuracy will continue on increasing: the model starts overfitting.
